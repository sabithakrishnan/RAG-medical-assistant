# %% [markdown]
# <a href="https://colab.research.google.com/github/sabithakrishnan/RAG-medical-assistant/blob/main/requirements_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
langchain
langchain-community
langchain-text-splitters
langchain-huggingface
chromadb
pypdf
requests
sentence-transformers
ragas
datasets
